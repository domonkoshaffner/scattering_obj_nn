# %% [markdown]
# ## Short description of the notebook
#
# This notebook was created and ran in google colab.
#
# This is an amendment to the main notebook. For further documantion, one shall see the main notebook.
#
# In this notebook, the NN is ran on the data without preprocessing it first.
#
# The notebook requires two files:
#  - Noisy_NearFieldData.txt: contains the data with noise
#  - Characteristics_no_rep.txt: contains the geometrical locations of the centers

# %% [markdown]
# ## Importing the necessary libraries

# %%
# Basic calculations and plotting 
import numpy as np
import matplotlib.pyplot as plt

# Generating random numbers
import random

# Prerocessing the data, splitting the dataset, calculating the accuracy
from sklearn import preprocessing
import skimage.measure
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Creating the NN
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Permute, Dense, Activation, LocallyConnected2D, Reshape, Flatten, Dropout, Input, Conv2D
from tensorflow.keras.models import Sequential, Model
import tensorflow.keras.optimizers

# %% [markdown]
# ## Loading the data

# %%
# Importing the dataset

x1 = np.genfromtxt("/content/Noisy_NearFieldData.txt", delimiter=' ')
y = np.genfromtxt("/content/Characteristics_no_rep.txt", delimiter=' ')

# We can delete the last column of the imported dataset, cause we don't calculate with the wavelength just yet

y = np.delete(y, [4], axis = 1)

# We transform the y-coordinates, so the norm is one

y = y+3
y = y/6

# Separating the dataset into list of lists

dataset = []

for i in range(0,16):
    dataset.append(x1[735*(i):735*(i+1)])

# %% [markdown]
# ## Function for splitting the dataset

# %%
# Splitting the matrix to train and test dataset
# Creating some lists to store the data
# Saving the train and test datasets to lists

def dataset_split(reduced_dataset, rand_state):

    combined_vector_train = []
    combined_vector_test = []

    for i in range(0,len(reduced_dataset)):
        x_train, x_test, y_train, y_test = train_test_split(reduced_dataset[i], y, test_size = 0.08, random_state = rand_state) 

        combined_vector_train.append(x_train)
        combined_vector_test.append(x_test)

    # Changing the dimensions of the matrices, so they are appropriate for the NN

    combined_vector_train = np.swapaxes(combined_vector_train,0,1)
    combined_vector_test = np.swapaxes(combined_vector_test,0,1)

    matrix_of_results = [combined_vector_train, combined_vector_test, y_train, y_test]

    return(matrix_of_results)

# %% [markdown]
# ## Creating the model and launching the neural network

# %%
# Setting the parameters of the NN

runs = 1
BATCH = 32
EPOCH = 250


for i in range (0,runs):

    # Generating a random number and using it as the random_state of the train-test splitting
    random_state = random.randint(0,100)
    # Calling the function of the splitting 
    results = dataset_split(dataset, random_state)

    # Saving the results in arrays
    combined_vector_train = results[0]
    combined_vector_test = results[1]
    y_train = results[2]
    y_test = results[3]

    # Creating the model
    model = Sequential()

    # Adding the layers
    model.add(Permute((2,1), input_shape=(16,161)))
    model.add(Reshape((16,161,1)))
    model.add(LocallyConnected2D(12,(1,4), activation='relu', use_bias=True))
    model.add(Dropout(0.5))
    model.add(Flatten())
    model.add(Dense(50, activation='relu'))
    model.add(Dense(40, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Flatten())
    model.add(Dense(4,activation='sigmoid'))
    
    # Setting the optimizer and compiling the model
    optimizer = keras.optimizers.Adam(learning_rate=0.0005, beta_1=0.9, beta_2=0.8, amsgrad=False)
    model.compile(loss='mse', optimizer=optimizer)
    
    # Fitting the model
    print("Run",i+1,"/",runs)
    history = model.fit(combined_vector_train, y_train, validation_data=(combined_vector_test, y_test), batch_size=BATCH, epochs=EPOCH, verbose = 1)
    
    # Calculating the different parameters of the model
    min_of_val_loss = np.min(history.history['val_loss'])
    index_of_min = history.history['val_loss'].index(min_of_val_loss)
    val_loss_min = '{:0.4f}'.format(min_of_val_loss)
    val_loss_final = '{:0.4f}'.format(history.history['val_loss'][EPOCH-1])
    
    # Plotting the validation- and training loss of the model
    plt.plot(history.history['loss'], color = 'orange', label='train loss')
    plt.plot(history.history['val_loss'], color = 'black', label='validation loss')
    plt.xlabel('epochs', fontsize=15)
    plt.ylabel('loss', fontsize=15)
    plt.legend(fontsize=15)
    plt.grid()
    plt.show()

    # Predicting the test values of the dataset
    predicted_values = np.matrix.round(model.predict(combined_vector_test)*6-3)
    y_test_pred_flat = np.ndarray.flatten(predicted_values)
    y_test_flat = np.ndarray.flatten(y_test)

    # Calculating the accuracy of the model
    acc = accuracy_score(y_test_flat*6-3, y_test_pred_flat)
    
    # Printing the results
    print('The accuracy of the model: ', round(acc,4))
    print("Validation loss =", '{:0.4f}'.format(history.history['val_loss'][EPOCH-1]))
    print('Minimum of validation loss:', '{:0.4f}'.format(min_of_val_loss), 'at EPOCH', index_of_min)
    print('Random state = ', random_state)
    print()
# Out:
# Run 1 / 1
# Epoch 1/250
# 22/22 [==============================] - 14s 633ms/step - loss: 0.1112 - val_loss: 0.1048
# Epoch 2/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.1102 - val_loss: 0.1039
# Epoch 3/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.1093 - val_loss: 0.1030
# Epoch 4/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.1084 - val_loss: 0.1022
# Epoch 5/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.1075 - val_loss: 0.1013
# Epoch 6/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.1067 - val_loss: 0.1005
# Epoch 7/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.1058 - val_loss: 0.0997
# Epoch 8/250
# 22/22 [==============================] - 1s 32ms/step - loss: 0.1050 - val_loss: 0.0989
# Epoch 9/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.1041 - val_loss: 0.0981
# Epoch 10/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.1033 - val_loss: 0.0973
# Epoch 11/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.1026 - val_loss: 0.0966
# Epoch 12/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.1018 - val_loss: 0.0959
# Epoch 13/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.1010 - val_loss: 0.0951
# Epoch 14/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.1003 - val_loss: 0.0944
# Epoch 15/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0995 - val_loss: 0.0937
# Epoch 16/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0988 - val_loss: 0.0930
# Epoch 17/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0981 - val_loss: 0.0924
# Epoch 18/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0974 - val_loss: 0.0917
# Epoch 19/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0967 - val_loss: 0.0911
# Epoch 20/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0961 - val_loss: 0.0904
# Epoch 21/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0954 - val_loss: 0.0899
# Epoch 22/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0948 - val_loss: 0.0893
# Epoch 23/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0942 - val_loss: 0.0887
# Epoch 24/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0936 - val_loss: 0.0881
# Epoch 25/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0930 - val_loss: 0.0876
# Epoch 26/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0925 - val_loss: 0.0871
# Epoch 27/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0919 - val_loss: 0.0866
# Epoch 28/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0914 - val_loss: 0.0861
# Epoch 29/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0909 - val_loss: 0.0856
# Epoch 30/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0904 - val_loss: 0.0851
# Epoch 31/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0899 - val_loss: 0.0847
# Epoch 32/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0894 - val_loss: 0.0842
# Epoch 33/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0889 - val_loss: 0.0838
# Epoch 34/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0885 - val_loss: 0.0834
# Epoch 35/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0881 - val_loss: 0.0830
# Epoch 36/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0877 - val_loss: 0.0827
# Epoch 37/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0873 - val_loss: 0.0823
# Epoch 38/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0869 - val_loss: 0.0819
# Epoch 39/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0865 - val_loss: 0.0816
# Epoch 40/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0862 - val_loss: 0.0813
# Epoch 41/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0858 - val_loss: 0.0810
# Epoch 42/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0855 - val_loss: 0.0807
# Epoch 43/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0852 - val_loss: 0.0804
# Epoch 44/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0849 - val_loss: 0.0801
# Epoch 45/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0846 - val_loss: 0.0798
# Epoch 46/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0843 - val_loss: 0.0796
# Epoch 47/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0840 - val_loss: 0.0794
# Epoch 48/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0838 - val_loss: 0.0791
# Epoch 49/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0835 - val_loss: 0.0789
# Epoch 50/250
# 22/22 [==============================] - 1s 33ms/step - loss: 0.0833 - val_loss: 0.0787
# Epoch 51/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0831 - val_loss: 0.0785
# Epoch 52/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0828 - val_loss: 0.0783
# Epoch 53/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0826 - val_loss: 0.0781
# Epoch 54/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0824 - val_loss: 0.0780
# Epoch 55/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0823 - val_loss: 0.0778
# Epoch 56/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0821 - val_loss: 0.0777
# Epoch 57/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0819 - val_loss: 0.0775
# Epoch 58/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0818 - val_loss: 0.0774
# Epoch 59/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0816 - val_loss: 0.0773
# Epoch 60/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0815 - val_loss: 0.0772
# Epoch 61/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0813 - val_loss: 0.0771
# Epoch 62/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0812 - val_loss: 0.0770
# Epoch 63/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0811 - val_loss: 0.0769
# Epoch 64/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0810 - val_loss: 0.0768
# Epoch 65/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0809 - val_loss: 0.0767
# Epoch 66/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0808 - val_loss: 0.0767
# Epoch 67/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0807 - val_loss: 0.0766
# Epoch 68/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0806 - val_loss: 0.0765
# Epoch 69/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0806 - val_loss: 0.0765
# Epoch 70/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0805 - val_loss: 0.0764
# Epoch 71/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0804 - val_loss: 0.0764
# Epoch 72/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0804 - val_loss: 0.0763
# Epoch 73/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0803 - val_loss: 0.0763
# Epoch 74/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0803 - val_loss: 0.0763
# Epoch 75/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0803 - val_loss: 0.0762
# Epoch 76/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0802 - val_loss: 0.0762
# Epoch 77/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0802 - val_loss: 0.0762
# Epoch 78/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0802 - val_loss: 0.0762
# Epoch 79/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0801 - val_loss: 0.0762
# Epoch 80/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0801 - val_loss: 0.0761
# Epoch 81/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0801 - val_loss: 0.0761
# Epoch 82/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0801 - val_loss: 0.0761
# Epoch 83/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0800 - val_loss: 0.0761
# Epoch 84/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0800 - val_loss: 0.0761
# Epoch 85/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0800 - val_loss: 0.0761
# Epoch 86/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0800 - val_loss: 0.0761
# Epoch 87/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0800 - val_loss: 0.0761
# Epoch 88/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0799 - val_loss: 0.0761
# Epoch 89/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0799 - val_loss: 0.0761
# Epoch 90/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0799 - val_loss: 0.0760
# Epoch 91/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0799 - val_loss: 0.0760
# Epoch 92/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0799 - val_loss: 0.0760
# Epoch 93/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0799 - val_loss: 0.0760
# Epoch 94/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0799 - val_loss: 0.0760
# Epoch 95/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0799 - val_loss: 0.0761
# Epoch 96/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0799 - val_loss: 0.0761
# Epoch 97/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0799 - val_loss: 0.0761
# Epoch 98/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0799 - val_loss: 0.0761
# Epoch 99/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0799 - val_loss: 0.0761
# Epoch 100/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0799 - val_loss: 0.0761
# Epoch 101/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 102/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 103/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 104/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 105/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 106/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 107/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 108/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 109/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 110/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 111/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 112/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 113/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 114/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 115/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 116/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 117/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 118/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 119/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 120/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 121/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 122/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 123/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 124/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 125/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 126/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 127/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 128/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 129/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 130/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 131/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 132/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 133/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 134/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 135/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 136/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 137/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 138/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 139/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 140/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 141/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 142/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 143/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 144/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 145/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 146/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 147/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 148/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0760
# Epoch 149/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0760
# Epoch 150/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0760
# Epoch 151/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0760
# Epoch 152/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0760
# Epoch 153/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0760
# Epoch 154/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 155/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 156/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 157/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 158/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 159/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 160/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 161/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 162/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 163/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 164/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 165/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 166/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 167/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 168/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 169/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 170/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 171/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 172/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 173/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 174/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 175/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 176/250
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 177/250
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 178/250
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 179/250
# 22/22 [==============================] - 1s 33ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 180/250
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 181/250
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 182/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 183/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 184/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 185/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 186/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 187/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 188/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 189/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 190/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 191/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 192/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 193/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 194/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 195/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 196/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 197/250
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 198/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 199/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 200/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 201/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 202/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 203/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 204/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 205/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 206/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 207/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 208/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 209/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 210/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 211/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 212/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 213/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 214/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 215/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 216/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 217/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 218/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 219/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 220/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 221/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 222/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 223/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 224/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 225/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 226/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 227/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 228/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 229/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 230/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 231/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 232/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 233/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 234/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 235/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 236/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 237/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 238/250
# 22/22 [==============================] - 1s 28ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 239/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 240/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 241/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 242/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 243/250
# 22/22 [==============================] - 1s 31ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 244/250
# 22/22 [==============================] - 1s 32ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 245/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 246/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 247/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 248/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 249/250
# 22/22 [==============================] - 1s 29ms/step - loss: 0.0798 - val_loss: 0.0761
# Epoch 250/250
# 22/22 [==============================] - 1s 30ms/step - loss: 0.0798 - val_loss: 0.0761
# The accuracy of the model:  0.2034
# Validation loss = 0.0761
# Minimum of validation loss: 0.0760 at EPOCH 149
# Random state =  80
